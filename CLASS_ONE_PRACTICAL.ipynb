# %% [markdown]
# <a href="https://colab.research.google.com/github/Belvinbarasa/Eng.barasa/blob/main/CLASS_ONE_PRACTICAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!!")
# Out:
# hello world!!

# %%
import pandas as pd # import the package and using 'pd' as the alias print ('pandas version : {}'. format(pd._version_))

# %%
data={'name':['sam','rob'], 'tittle' : ['physicist', 'economist']}

# %%
data
# Out:
# {'name': ['sam', 'rob'], 'tittle': ['physicist', 'economist']}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   name     tittle
# 0  sam  physicist
# 1  rob  economist

# %%
data={'Name': ['Sam', 'Rob', 'Jack', 'Jill', 'Dave', 'Alex', 'Steve'],\
      'Title': ['Physicist', 'Economist', 'Statistician', 'Data Scientist', 'Designer', 'Architect', 'Doctor'], \
      'Age': [59, 66, 42, 28, 24, 39, 52],\
      'City': ['Melbourne', 'Melbourne', 'Sydney', 'Sydney', 'Melbourne', 'Perth', 'Brisbane'],\
      'University': ['Monash', 'Monash', 'UNSW', 'UTS', 'Uni mel', 'UWA', 'UQ']}

# %%
df = pd.DataFrame(data)
df
# Out:
#     Name           Title  Age       City University
# 0    Sam       Physicist   59  Melbourne     Monash
# 1    Rob       Economist   66  Melbourne     Monash
# 2   Jack    Statistician   42     Sydney       UNSW
# 3   Jill  Data Scientist   28     Sydney        UTS
# 4   Dave        Designer   24  Melbourne    Uni mel
# 5   Alex       Architect   39      Perth        UWA
# 6  Steve          Doctor   52   Brisbane         UQ

# %%
df.head(2)##Displays the first 2 rows of the dataframe
# Out:
#   Name      Title  Age       City University
# 0  Sam  Physicist   59  Melbourne     Monash
# 1  Rob  Economist   66  Melbourne     Monash

# %%
df.tail()
# Out:
#     Name           Title  Age       City University
# 2   Jack    Statistician   42     Sydney       UNSW
# 3   Jill  Data Scientist   28     Sydney        UTS
# 4   Dave        Designer   24  Melbourne    Uni mel
# 5   Alex       Architect   39      Perth        UWA
# 6  Steve          Doctor   52   Brisbane         UQ

# %%
df.tail(1)
# Out:
#     Name   Title  Age      City University
# 6  Steve  Doctor   52  Brisbane         UQ

# %%
df[df['City'] == 'Sydney']
# Out:
#    Name           Title  Age    City University
# 2  Jack    Statistician   42  Sydney       UNSW
# 3  Jill  Data Scientist   28  Sydney        UTS

# %%
df[(df['City'] == 'Melbourne') & (df['University'] == 'Monash')]
# Out:
#   Name      Title  Age       City University
# 0  Sam  Physicist   59  Melbourne     Monash
# 1  Rob  Economist   66  Melbourne     Monash

# %%
df[df['Age']<=35]
# Out:
#    Name           Title  Age       City University
# 3  Jill  Data Scientist   28     Sydney        UTS
# 4  Dave        Designer   24  Melbourne    Uni mel

# %%
df[(df['City'] == 'Melbourne') & (df['Age']>=55)]
# Out:
#   Name      Title  Age       City University
# 0  Sam  Physicist   59  Melbourne     Monash
# 1  Rob  Economist   66  Melbourne     Monash

# %%
df.iloc[1:3]
# Out:
#    Name         Title  Age       City University
# 1   Rob     Economist   66  Melbourne     Monash
# 2  Jack  Statistician   42     Sydney       UNSW

# %%
df.iloc[1:2]
# Out:
#   Name      Title  Age       City University
# 1  Rob  Economist   66  Melbourne     Monash

# %%
df.iloc[1]
# Out:
# Name                Rob
# Title         Economist
# Age                  66
# City          Melbourne
# University       Monash
# Name: 1, dtype: object

# %%
df
# Out:
#     Name           Title  Age       City University
# 0    Sam       Physicist   59  Melbourne     Monash
# 1    Rob       Economist   66  Melbourne     Monash
# 2   Jack    Statistician   42     Sydney       UNSW
# 3   Jill  Data Scientist   28     Sydney        UTS
# 4   Dave        Designer   24  Melbourne    Uni mel
# 5   Alex       Architect   39      Perth        UWA
# 6  Steve          Doctor   52   Brisbane         UQ

# %%
df.loc[2, 'Age'] = 43

# %%
df
# Out:
#     Name           Title  Age       City University
# 0    Sam       Physicist   59  Melbourne     Monash
# 1    Rob       Economist   66  Melbourne     Monash
# 2   Jack    Statistician   43     Sydney       UNSW
# 3   Jill  Data Scientist   28     Sydney        UTS
# 4   Dave        Designer   24  Melbourne    Uni mel
# 5   Alex       Architect   39      Perth        UWA
# 6  Steve          Doctor   52   Brisbane         UQ

# %%
df.to_csv('researchers.csv', index=False)

# %%
k=pd.read_csv('/content/data.csv')## new data set

# %%
k
# Out:
#      feature_1  feature_2 category_column  missing_values  duplicate_column
# 0     4.967142  42.923146               B             NaN                 2
# 1    -1.382643  47.896773               B            86.0                 1
# 2     6.476885  48.286427               A            57.0                 5
# 3    15.230299  45.988614               A            29.0                 4
# 4    -2.341534  49.193571               A            78.0                 1
# ..         ...        ...             ...             ...               ...
# 100   4.967142  42.923146               B             NaN                 2
# 101  -1.382643  47.896773               B            86.0                 1
# 102   6.476885  48.286427               A            57.0                 5
# 103  15.230299  45.988614               A            29.0                 4
# 104  -2.341534  49.193571               A            78.0                 1
#
# [105 rows x 5 columns]

# %%
df
# Out:
#     Name           Title  Age       City University
# 0    Sam       Physicist   59  Melbourne     Monash
# 1    Rob       Economist   66  Melbourne     Monash
# 2   Jack    Statistician   43     Sydney       UNSW
# 3   Jill  Data Scientist   28     Sydney        UTS
# 4   Dave        Designer   24  Melbourne    Uni mel
# 5   Alex       Architect   39      Perth        UWA
# 6  Steve          Doctor   52   Brisbane         UQ

# %%
import json

# %%
#convert from JSON to Python

#some #JSON:
x = '{"name":"John", "age":30, "city':"New York"}'
# parse x:
y =json.loads(x)
# the result is a Python dictionary:
print(y["age"])
# Out:
#   File "<ipython-input-110-2ef0eeeecfff>", line 4
#     x = '{"name":"John", "age":30, "city':"New York"}'
#                                                     ^
# SyntaxError: unmatched '}'
