# %% [markdown]
# <a href="https://colab.research.google.com/github/Belvinbarasa/Eng.barasa/blob/main/Hypothesis_testing_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Generate Sample Dataset
data = {
    'ID': range(1, 11),
    'Latitude': np.random.uniform(-1.3, -1.2, 10), # Random latitudes
    'Longitude': np.random.uniform(36.7, 36.9, 10), # Random longitudes
    'Value': np.random.randint(10, 100, 10) # Random values
}
df = pd.DataFrame(data)

# %%
# Exploratory Data Analysis (EDA)
print("Dataset Overview:\n", df.head())
print("\nSummary Statistics:\n", df.describe())
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Dataset Overview:
#     ID  Latitude  Longitude  Value
# 0   1 -1.292910  36.789749     83
# 1   2 -1.215179  36.785374     39
# 2   3 -1.250976  36.825335     56
# 3   4 -1.220729  36.721611     37
# 4   5 -1.246193  36.702726     68
#
# Summary Statistics:
#               ID   Latitude  Longitude      Value
# count  10.00000  10.000000  10.000000  10.000000
# mean    5.50000  -1.243538  36.778272  56.900000
# std     3.02765   0.029713   0.069542  18.976301
# min     1.00000  -1.292910  36.702726  30.000000
# 25%     3.25000  -1.253043  36.724400  42.250000
# 50%     5.50000  -1.238534  36.764736  54.500000
# 75%     7.75000  -1.221115  36.816438  67.000000
# max    10.00000  -1.210725  36.899920  87.000000
#
# Missing Values:
#  ID           0
# Latitude     0
# Longitude    0
# Value        0
# dtype: int64

# %%
# Box Plot
plt.figure(figsize=(8, 6))
sns.boxplot(data=df[['Value']])
plt.title("Box Plot of Values")
plt.show()

# %%
# Pair Plot
sns.pairplot(df)
plt.show()
